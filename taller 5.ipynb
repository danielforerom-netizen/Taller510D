# %%
print("hola mundo")
# Out:
# Running cells with 'Python 3.14.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Estudiante/AppData/Roaming/uv/python/cpython-3.14.7-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
nombre = "Daniel Forero" 
print(nombre)
# Out:
# Running cells with 'Python 3.14.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Estudiante/AppData/Roaming/uv/python/cpython-3.14.7-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("Hola mundo,mi nombre es Daniel Forero")

# %%
print(3+2)

# %%
print(4*3)

# %%
print(4/123)

# %%
print(78-44)
